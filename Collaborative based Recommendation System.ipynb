# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing Datasets

# %%
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Ratings.csv')
# Out:
# C:\Users\Nithin\AppData\Local\Temp\ipykernel_21372\2285880890.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %% [markdown]
# ## Data Accessing

# %%
print(books.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (1149780, 3)

# %%
print(books.columns)
print(ratings.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books.dropna(inplace=True)

# %%
books.shape
# Out:
# (271353, 8)

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
#mergeing 2 datasets on "ISBN"

merge_df = books.merge(ratings,on='ISBN')

# %%
merge_df.shape
# Out:
# (1031128, 10)

# %%
merge_df.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
# ...

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031128 entries, 0 to 1031127
# Data columns (total 10 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ISBN                 1031128 non-null  object
#  1   Book-Title           1031128 non-null  object
#  2   Book-Author          1031128 non-null  object
#  3   Year-Of-Publication  1031128 non-null  object
#  4   Publisher            1031128 non-null  object
#  5   Image-URL-S          1031128 non-null  object
#  6   Image-URL-M          1031128 non-null  object
#  7   Image-URL-L          1031128 non-null  object
#  8   User-ID              1031128 non-null  int64
#  9   Book-Rating          1031128 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 78.7+ MB

# %% [markdown]
# # Collobrative based recomm.system

# %%
merge_df
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031123  0440400988                         There's a Bat in Bunk Five
# 1031124  0525447644                            From One to One Hundred
# 1031125  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031126  0192126040                        Republic (World's Classics)
# 1031127  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# ...

# %%
df = merge_df.drop(columns=['ISBN','Year-Of-Publication','Image-URL-S','Image-URL-L'])

# %%
df.head()
# Out:
#             Book-Title           Book-Author                Publisher  \
# 0  Classical Mythology    Mark P. O. Morford  Oxford University Press
# 1         Clara Callan  Richard Bruce Wright    HarperFlamingo Canada
# 2         Clara Callan  Richard Bruce Wright    HarperFlamingo Canada
# 3         Clara Callan  Richard Bruce Wright    HarperFlamingo Canada
# 4         Clara Callan  Richard Bruce Wright    HarperFlamingo Canada
#
#                                          Image-URL-M  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...        2            0
# 1  http://images.amazon.com/images/P/0002005018.0...        8            5
# 2  http://images.amazon.com/images/P/0002005018.0...    11400            0
# 3  http://images.amazon.com/images/P/0002005018.0...    11676            8
# 4  http://images.amazon.com/images/P/0002005018.0...    41385            0

# %%
df['User-ID'].value_counts() #92106 unique users
# Out:
# User-ID
# 11676     11144
# 198711     6456
# 153662     5814
# 98391      5777
# 35859      5646
#           ...
# 51911         1
# 151772        1
# 158802        1
# 243672        1
# 259920        1
# Name: count, Length: 92106, dtype: int64

# %%
df.groupby('User-ID').count()
# Out:
#          Book-Title  Book-Author  Publisher  Image-URL-M  Book-Rating
# User-ID
# 2                 1            1          1            1            1
# 8                17           17         17           17           17
# 9                 3            3          3            3            3
# 10                1            1          1            1            1
# 12                1            1          1            1            1
# ...             ...          ...        ...          ...          ...
# 278846            1            1          1            1            1
# 278849            4            4          4            4            4
# 278851           23           23         23           23           23
# 278852            1            1          1            1            1
# 278854            8            8          8            8            8
#
# [92106 rows x 5 columns]

# %%
df.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
df.groupby('User-ID').count()['Book-Rating'] > 200
# Out:
# User-ID
# 2         False
# 8         False
# 9         False
# 10        False
# 12        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: Book-Rating, Length: 92106, dtype: bool

# %%
 x= df.groupby('User-ID').count()['Book-Rating'] > 200

# %%
x[x] #1648 users out of 92106 gave rating for more than 100 books
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274308    True
# 275970    True
# 277427    True
# 277639    True
# 278418    True
# Name: Book-Rating, Length: 811, dtype: bool

# %%
x[x].index
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=811)

# %%
temp_df = x[x].index

# %%
df['User-ID'].isin(temp_df)
# Out:
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 1031123    False
# 1031124    False
# 1031125    False
# 1031126    False
# 1031127    False
# Name: User-ID, Length: 1031128, dtype: bool

# %%
df[df['User-ID'].isin(temp_df)]
# Out:
#                                                 Book-Title  \
# 3                                             Clara Callan
# 6                                             Clara Callan
# 7                                             Clara Callan
# 10                                            Clara Callan
# 21       Flu: The Story of the Great Influenza Pandemic...
# ...                                                    ...
# 1031116                      Slow Food(The Case For Taste)
# 1031117  Strong Democracy : Participatory Politics for ...
# 1031118  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 1031119  Tropical Rainforests: 230 Species in Full Colo...
# 1031120                                  Cocktail Classics
#
#                    Book-Author                              Publisher  \
# 3         Richard Bruce Wright                  HarperFlamingo Canada
# 6         Richard Bruce Wright                  HarperFlamingo Canada
# ...

# %%
filtered_on_bases_of_users_df = df[df['User-ID'].isin(temp_df)]

# %%
# 1031129 rows in 'merge_df' filtered to 591891 rows on the bases of users who rated for more than 100 books

# %%
filtered_on_bases_of_users_df
# Out:
#                                                 Book-Title  \
# 3                                             Clara Callan
# 6                                             Clara Callan
# 7                                             Clara Callan
# 10                                            Clara Callan
# 21       Flu: The Story of the Great Influenza Pandemic...
# ...                                                    ...
# 1031116                      Slow Food(The Case For Taste)
# 1031117  Strong Democracy : Participatory Politics for ...
# 1031118  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 1031119  Tropical Rainforests: 230 Species in Full Colo...
# 1031120                                  Cocktail Classics
#
#                    Book-Author                              Publisher  \
# 3         Richard Bruce Wright                  HarperFlamingo Canada
# 6         Richard Bruce Wright                  HarperFlamingo Canada
# ...

# %%
filtered_on_bases_of_users_df['Image-URL-M'][3]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
# filter on bases of popular books
filtered_on_bases_of_users_df.groupby('Book-Title').count()
# Out:
#                                                     Book-Author  Publisher  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...            2          2
#  Always Have Popsicles                                        1          1
#  Apple Magic (The Collector's series)                         1          1
#  Beyond IBM: Leadership Marketing and Finance f...            1          1
#  Clifford Visita El Hospital (Clifford El Gran ...            1          1
# ...                                                         ...        ...
# Ã?Â?ber das Fernsehen.                                        2          2
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den St...            3          3
# Ã?Â?lpiraten.                                                 1          1
# Ã?Â?stlich der Berge.                                         1          1
# Ã?Â?thique en toc                                             1          1
#
# ...

# %%
filtered_on_bases_of_users_df.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    2
#  Always Have Popsicles                                                                                        1
#  Apple Magic (The Collector's series)                                                                         1
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#  Clifford Visita El Hospital (Clifford El Gran Perro Colorado)                                                1
#                                                                                                              ..
# Ã?Â?ber das Fernsehen.                                                                                        2
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.                                                           3
# ...

# %%
filtered_on_bases_of_users_df.groupby('Book-Title').count()['Book-Rating'] > 50
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    False
#  Always Have Popsicles                                                                                        False
#  Apple Magic (The Collector's series)                                                                         False
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   False
#  Clifford Visita El Hospital (Clifford El Gran Perro Colorado)                                                False
#                                                                                                               ...
# Ã?Â?ber das Fernsehen.                                                                                        False
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.                                                           False
# ...

# %%
y = filtered_on_bases_of_users_df.groupby('Book-Title').count()['Book-Rating'] > 50

# %%
y[y]
# Out:
# Book-Title
# 1984                                                                 True
# 1st to Die: A Novel                                                  True
# 2nd Chance                                                           True
# 4 Blondes                                                            True
# A Bend in the Road                                                   True
#                                                                      ...
# Year of Wonders                                                      True
# You Belong To Me                                                     True
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values    True
# Zoya                                                                 True
# \O\" Is for Outlaw"                                                  True
# Name: Book-Rating, Length: 679, dtype: bool

# %%
y[y].index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=679)

# %%
temp_df = y[y].index

# %%
final_df = filtered_on_bases_of_users_df[filtered_on_bases_of_users_df['Book-Title'].isin(temp_df)]

# %%
final_df
# Out:
#                               Book-Title      Book-Author  \
# 31                The Kitchen God's Wife          Amy Tan
# 33                The Kitchen God's Wife          Amy Tan
# 34                The Kitchen God's Wife          Amy Tan
# 38                The Kitchen God's Wife          Amy Tan
# 39                The Kitchen God's Wife          Amy Tan
# ...                                  ...              ...
# 1028407                           Echoes      Nancy Morse
# 1028593  I Know Why the Caged Bird Sings     Maya Angelou
# 1028595                      The Promise      CHAIM POTOK
# 1028808         The Pillars of the Earth      Ken Follett
# 1028810              The Handmaid's Tale  Margaret Atwood
#
#                              Publisher  \
# 31                    Putnam Pub Group
# 33                    Putnam Pub Group
# 34                    Putnam Pub Group
# 38                    Putnam Pub Group
# 39                    Putnam Pub Group
# ...

# %%
pt = final_df.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt #679 books & 810 users
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
# each books represented as a vector in 810 dimensional space.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(pt) # A 2D numpy array that gives Euclidean distance of each book with 679 other books
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
cosine_similarity(pt).shape
# Out:
# (679, 679)

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
def recommend(book_name):
    #fetchind index
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])),key = lambda x:x[1],reverse=True)[1:6]
    
    for i in similar_items:
        print(pt.index[i[0]])

# %%
recommend('Message in a Bottle')
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes

# %%
recommend('Zoya')
# Out:
# Fine Things
# Secrets
# Kaleidoscope
# Exclusive
# Five Days in Paris

# %%
recommend("Harry Potter and the Sorcerer's Stone (Book 1)")
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Order of the Phoenix (Book 5)
# The Mists of Avalon

# %%
#np.where(pt.index == 'You Belong To Me')[0][0]

# %%
#list(enumerate(similarity_score[675])) #along with distance, index also displayed

# %%
#sorted(list(enumerate(similarity_score[675]))) # here sorting is on the bases of index

# %%
#sorted(list(enumerate(similarity_score[675])),key = lambda x:x[1],reverse=True)[1:6]
